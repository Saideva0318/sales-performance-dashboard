# %% [markdown]
# # Sales Performance Exploratory Analysis
# Notebook for EDA and prototyping before production code.

# %%
import sys
sys.path.insert(0, '../src')
import pandas as pd
import plotly.express as px
from data_loader import load_data
from transformations import clean_data, engineer_features, compute_kpis

df = engineer_features(clean_data(load_data()))
kpis = compute_kpis(df)
print(kpis)
